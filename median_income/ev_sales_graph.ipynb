# %%
import pandas as pd
sale_data = pd.read_csv(r'C:\Users\shahs\Documents\Year 4 College\DS 2500\Project\ev_sale_data.csv')
print(sale_data)
# Out:
#                        Model  Count  Year  Type
# 0                 Chevy Volt   7671  2011  PHEV
# 1                Nissan Leaf   9674  2011    EV
# 2                   Smart ED    342  2011    EV
# 3            Mitsubishi I EV     76  2011    EV
# 4               BMW Active E      0  2011    EV
# ..                       ...    ...   ...   ...
# 490            Jaguar I-Pace   2594  2019    EV
# 491    Hyundai Kona Electric   1721  2019    EV
# 492  Subaru Crosstrek Hybrid    880  2019  PHEV
# 493              Audi e-tron   5369  2019    EV
# 494              Kia Niro EV   1562  2019    EV
#
# [495 rows x 4 columns]

# %%
pivot_df = sale_data.pivot(index='Year', columns='Model', values='Count')
pivot_df
# Out:
# Model  Audi A3 Plug In  Audi e-tron  BMW 3-series Plug-In  \
# Year
# 2011                 0            0                     0
# 2012                 0            0                     0
# 2013                 0            0                     0
# 2014                 0            0                     0
# 2015                 0            0                     0
# 2016              4280            0                   880
# 2017              2877            0                  4141
# 2018              2597            0                  2600
# 2019               437         5369                   705
#
# Model  BMW 5-Series Plug in  BMW 7-series Plug-in  BMW Active E  BMW X5  \
# Year
# 2011                      0                     0             0       0
# 2012                      0                     0           673       0
# 2013                      0                     0             0       0
# 2014                      0                     0             0       0
# 2015                      0                     0             0     892
# 2016                      0                    23             0    5995
# 2017                   3759                   707             0    5349
# 2018                   8664                   339             0    4434
# 2019                   5442                    80             0     167
#
# Model  BMW i3  BMW i8  Cadillac CT6  ...  Smart ED  Subaru Crosstrek Hybrid  \
# Year                                 ...
# 2011        0       0             0  ...       342                        0
# 2012        0       0             0  ...       139                        0
# 2013        0       0             0  ...       923                        0
# 2014     6092     555             0  ...      2594                        0
# 2015    11024    2265             0  ...      1387                        0
# 2016     7625    1594             0  ...       657                        0
# 2017     6276     488           205  ...       544                        0
# 2018     6117     772           231  ...      1219                        0
# 2019     4854    1102            25  ...       680                      880
#
# Model  Tesla Model 3  Tesla Model S  Tesla Model X  Toyota RAV4 EV  VW e-Golf  \
# Year
# 2011               0              0              0               0          0
# 2012               0           2400              0             192          0
# 2013               0          19400              0            1005          0
# 2014               0          16750              0            1184        357
# 2015               0          26200            208              18       4232
# 2016               0          30200          19600               0       3937
# 2017            1770          26500          21700               0       3534
# 2018          139782          25745          26100               0       1354
# 2019          154840          15090          19425               0       4863
#
# Model  Volvo S90 Plug In  Volvo XC60 Plug In  Volvo-XC90 Plug In
# Year
# 2011                   0                   0                   0
# 2012                   0                   0                   0
# 2013                   0                   0                   0
# 2014                   0                   0                   0
# 2015                   0                   0                  86
# 2016                   0                   0                2015
# 2017                 112                 356                2358
# 2018                 437                2267                1387
# 2019                 407                1682                1710
#
# [9 rows x 55 columns]

# %%
pivot_df.loc[:,['Chevy Volt','Nissan Leaf','Smart ED','Mitsubishi I EV','BMW Active E','Prius PHEV','Ford Focus EV','Honda Fit EV',
                'Tesla Model S','Toyota RAV4 EV','Ford C-Max Energi','Honda Accord','Ford Fusion Energi','Chevy Spark','Fiat 500E',
                'Porsche Panamera S E-Hybrid','Cadillac ELR','BMW i3','Mercedes B-Class (B250e)','BMW i8','VW e-Golf','Kia Soul EV',
                'Porsche Cayenne S E-Hybrid','Mercedes S550 Plug', 'Volvo-XC90 Plug In', 'Tesla Model X','BMW X5', 'Hyundai Sonata Plug In',
                'Audi A3 Plug In', 'BMW 3-series Plug-In', 'Mercedes GLE 550e', 'BMW 7-series Plug-in', 'Mercedes C350We','Chevy Bolt',
                'Kia Optima Plug-in','Hyundai Ioniq EV','Chrysler Pacifica Plug-in Hybrid','Cadillac CT6','BMW 5-Series Plug in','MINI Countryman S E',
                'Porsche Panamera 4 E-H', 'Tesla Model 3','Honda Clarity BEV', 'Volvo XC60 Plug In', 'Volvo S90 Plug In','Honda Clarity Plug-in',
                'Mitsubishi Outlander Plug In','Hyundai Ioniq Plug-In','Kia Niro Plug In','Mercedes GLC 350e Hybrid','Jaguar I-Pace',
                'Hyundai Kona Electric', 'Subaru Crosstrek Hybrid','Audi e-tron','Kia Niro EV']].plot.bar(stacked=True, figsize=(25,17.5), title = "US PEV Sales by Model]")
# Out:
# <AxesSubplot:title={'center':'US PEV Sales by Model'}, xlabel='Year'>
