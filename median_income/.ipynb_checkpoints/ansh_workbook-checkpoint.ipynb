# %%
import pandas as pd
import numpy as np
import geopandas
import matplotlib.pyplot as plt
from shapely.geometry import Point

# import missingno as msn

import seaborn as sns

# %%
data = pd.read_csv('stations_2021.csv')

data = data[data['Fuel Type Code'] == 'ELEC']

data
# Out:
# /Users/aidanwebster/opt/anaconda3/envs/geo_env/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (3,6,10,13,14,15,16,20,29,31,33,34,35,36,43,45,46,47,49,52,53,54,56,57,58,59,60,61,62,63) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Fuel Type Code                                       Station Name  \
# 159             ELEC                           LADWP - Truesdale Center
# 160             ELEC                    LADWP - West LA District Office
# 161             ELEC  Southern California Edison - Rosemead Office B...
# 162             ELEC                      Los Angeles Convention Center
# 163             ELEC                      LADWP - John Ferraro Building
# ...              ...                                                ...
# 56789           ELEC                                        SWEC_ SWEC2
# 56790           ELEC                       Calabasas Rondell Smart Park
# 56791           ELEC                                  Figueroa Plaza P2
# 56792           ELEC                                  Figueroa Plaza P3
# 56793           ELEC                                  Figueroa Plaza P4
#
#               Street Address   Intersection Directions         City State  \
# 159       11797 Truesdale St                       NaN   Sun Valley    CA
# 160    1394 S Sepulveda Blvd                       NaN  Los Angeles    CA
# 161    2244 Walnut Grove Ave                       NaN     Rosemead    CA
# 162       1201 S Figueroa St  West hall and South hall  Los Angeles    CA
# 163            111 N Hope St               Across Hope  Los Angeles    CA
# ...                      ...                       ...          ...   ...
# 56789            6800 RT 162                       NaN    Maryville    IL
# 56790      23600 Rondell St.                       NaN    Calabasas    CA
# 56791      201 N Figueroa St                       NaN  Los Angeles    CA
# 56792      201 N Figueroa St                       NaN  Los Angeles    CA
# 56793      201 N Figueroa St                       NaN  Los Angeles    CA
#
#          ZIP  Plus4 Station Phone Status Code  ... EV Pricing (French)  \
# 159    91352    NaN           NaN           E  ...                 NaN
# 160    90024    NaN           NaN           E  ...                 NaN
# 161    91770    NaN           NaN           T  ...                 NaN
# 162    90015    NaN  213-741-1151           E  ...                 NaN
# 163    90012    NaN           NaN           E  ...                 NaN
# ...      ...    ...           ...         ...  ...                 ...
# 56789  62062    NaN  888-758-4389           E  ...                 NaN
# 56790  91301    NaN  877-455-3833           E  ...                 NaN
# 56791  90012    NaN  855-900-7584           E  ...                 NaN
# 56792  90012    NaN  855-900-7584           E  ...                 NaN
# 56793  90012    NaN  855-900-7584           E  ...                 NaN
#
#       LPG Nozzle Types Hydrogen Pressures Hydrogen Standards  \
# 159                NaN                NaN                NaN
# 160                NaN                NaN                NaN
# 161                NaN                NaN                NaN
# 162                NaN                NaN                NaN
# 163                NaN                NaN                NaN
# ...                ...                ...                ...
# 56789              NaN                NaN                NaN
# 56790              NaN                NaN                NaN
# 56791              NaN                NaN                NaN
# 56792              NaN                NaN                NaN
# 56793              NaN                NaN                NaN
#
#       CNG Fill Type Code CNG PSI CNG Vehicle Class  LNG Vehicle Class  \
# 159                  NaN     NaN               NaN                NaN
# 160                  NaN     NaN               NaN                NaN
# 161                  NaN     NaN               NaN                NaN
# 162                  NaN     NaN               NaN                NaN
# 163                  NaN     NaN               NaN                NaN
# ...                  ...     ...               ...                ...
# 56789                NaN     NaN               NaN                NaN
# 56790                NaN     NaN               NaN                NaN
# 56791                NaN     NaN               NaN                NaN
# 56792                NaN     NaN               NaN                NaN
# 56793                NaN     NaN               NaN                NaN
#
#        EV On-Site Renewable Source  Restricted Access
# 159                            NaN                NaN
# 160                            NaN                NaN
# 161                            NaN                NaN
# 162                            NaN                NaN
# 163                            NaN                NaN
# ...                            ...                ...
# 56789                          NaN                NaN
# 56790                          NaN                NaN
# 56791                          NaN                NaN
# 56792                          NaN                NaN
# 56793                          NaN                NaN
#
# [47086 rows x 65 columns]

# %%
gdf = geopandas.GeoDataFrame(data, geometry=geopandas.points_from_xy(data.Longitude, data.Latitude))
# print(gdf.head())

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

# We restrict to South America.
ax = world[world.continent == 'North America'].plot(
    color='white', edgecolor='black',figsize=(16,16))

# We can now plot our ``GeoDataFrame``.
gdf.plot(ax=ax, color='green',marker='o', markersize=6)

plt.show()

# %%
country = geopandas.read_file('gz_2010_us_040_00_5m.json')

# country[country['NAME'].isin(['Alaska','Hawaii']) == False].plot(figsize=(30,20), color='#3B3C6E');

geo = geopandas.GeoDataFrame(data, geometry='geometry')
type(data['geometry'])


# geo.plot(figsize=(20,10));

fig, ax = plt.subplots(1, figsize=(30,20))

base = country[country['NAME'].isin(['Alaska','Hawaii']) == False].plot(ax=ax, color='#3B3C6E')

geo.plot(ax=base, color='green', marker="*", markersize=15);
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: gz_2010_us_040_00_5m.json: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# /var/folders/xg/0k7m6jxd3px6rpn4kgj3dlgm0000gn/T/ipykernel_39332/1891070213.py in <module>
# ----> 1 country = geopandas.read_file('gz_2010_us_040_00_5m.json')
#       2
#       3 # country[country['NAME'].isin(['Alaska','Hawaii']) == False].plot(figsize=(30,20), color='#3B3C6E');
#       4
#       5 geo = geopandas.GeoDataFrame(data, geometry='geometry')
#
# ~/opt/anaconda3/envs/geo_env/lib/python3.10/site-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#     199
#     200     with fiona_env():
# --> 201         with reader(path_or_bytes, **kwargs) as features:
#     202
#     203             # In a future Fiona release the crs attribute of features will
#
# ~/opt/anaconda3/envs/geo_env/lib/python3.10/site-packages/fiona/env.py in wrapper(*args, **kwargs)
#     406     def wrapper(*args, **kwargs):
#     407         if local._env:
# --> 408             return f(*args, **kwargs)
#     409         else:
#     410             if isinstance(args[0], str):
#
# ~/opt/anaconda3/envs/geo_env/lib/python3.10/site-packages/fiona/__init__.py in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     254
#     255         if mode in ('a', 'r'):
# --> 256             c = Collection(path, mode, driver=driver, encoding=encoding,
#     257                            layer=layer, enabled_drivers=enabled_drivers, **kwargs)
#     258         elif mode == 'w':
#
# ~/opt/anaconda3/envs/geo_env/lib/python3.10/site-packages/fiona/collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     160             if self.mode == 'r':
#     161                 self.session = Session()
# --> 162                 self.session.start(self, **kwargs)
#     163             elif self.mode in ('a', 'w'):
#     164                 self.session = WritingSession()
#
# fiona/ogrext.pyx in fiona.ogrext.Session.start()
#
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# DriverError: gz_2010_us_040_00_5m.json: No such file or directory
